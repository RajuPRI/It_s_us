# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nax=np.arange(1,9)
nax
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
nay=np.arange(3,27,3)
nay
# Out:
# array([ 3,  6,  9, 12, 15, 18, 21, 24])

# %%
plt.plot(nax,nay)

# %%
plt.bar(nax,nay)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.barh(nax,nay)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.polar(nax,nay)

# %%
plt.step(nax,nay)

# %%
from pylab import *

# %%
x=linspace(-3,3,30)
y=x**2
plot(x,y)
